# %%
import pandas as pd
import numpy as np

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.11.17)

# %%
import folium

# %%
df = pd.read_csv("dee-2424.csv",encoding="latin1",skiprows=1)
df
# Out:
#                  Município     ibge  latitude  longitude  \
# 0                   Aceguá  4300034 -31.86076  -54.16706
# 1               Água Santa  4300059 -28.16720  -52.03100
# 2                    Agudo  4300109 -29.64470  -53.25150
# 3                Ajuricaba  4300208 -28.23420  -53.77570
# 4                  Alecrim  4300307 -27.65790  -54.76490
# ..                     ...      ...       ...        ...
# 492  Vista Alegre do Prata  4323606 -28.80520  -51.79460
# 493           Vista Gaúcha  4323705 -27.29020  -53.69740
# 494    Vitória das Missões  4323754 -28.35160  -54.50400
# 495              Westfalia  4323770 -29.37440  -51.74630
# 496              Xangri-lá  4323804 -29.80650  -50.05190
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1992 (litros)  \
# 0                                                    -
# 1                                              357.050
# 2                                            1.252.900
# 3                                              974.480
# 4                                              434.150
# ..                                                 ...
# 492                                             75.000
# 493                                            153.450
# 494                                                  -
# 495                                                  -
# 496                                                  -
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1993 (litros)  \
# 0                                                    -
# 1                                              250.400
# 2                                            1.147.250
# 3                                              945.950
# 4                                              421.300
# ..                                                 ...
# 492                                             50.000
# 493                                            107.850
# 494                                                  -
# 495                                                  -
# 496                                                  -
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1994 (litros)  \
# 0                                                    -
# 1                                              181.650
# 2                                            1.142.350
# 3                                              959.000
# 4                                              441.000
# ..                                                 ...
# 492                                              5.000
# 493                                            118.900
# 494                                                  -
# 495                                                  -
# 496                                                  -
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1995 (litros)  \
# 0                                                    -
# 1                                              193.750
# 2                                            1.215.800
# 3                                              975.000
# 4                                              452.050
# ..                                                 ...
# 492                                                  -
# 493                                             81.800
# 494                                            110.000
# 495                                                  -
# 496                                                  -
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1996 (litros)  \
# 0                                                    -
# 1                                              204.600
# 2                                            1.235.100
# 3                                            1.029.000
# 4                                              531.450
# ..                                                 ...
# 492                                                  -
# 493                                            115.000
# 494                                            195.000
# 495                                                  -
# 496                                             82.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1997 (litros)  ...  \
# 0                                                    -                  ...
# 1                                              201.800                  ...
# 2                                            1.211.750                  ...
# 3                                            1.049.600                  ...
# 4                                              549.650                  ...
# ..                                                 ...                  ...
# 492                                                  -                  ...
# 493                                             90.000                  ...
# 494                                            177.000                  ...
# 495                                                  -                  ...
# 496                                            904.000                  ...
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2011 (litros)  \
# 0                                              775.000
# 1                                              446.000
# 2                                            3.010.500
# 3                                            1.231.000
# 4                                              905.000
# ..                                                 ...
# 492                                            286.000
# 493                                            321.000
# 494                                            221.000
# 495                                            801.000
# 496                                          6.061.500
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2012 (litros)  \
# 0                                            1.523.000
# 1                                              513.000
# 2                                            3.390.000
# 3                                            1.343.000
# 4                                              949.000
# ..                                                 ...
# 492                                            246.000
# 493                                            368.000
# 494                                            255.000
# 495                                            826.500
# 496                                          6.262.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2013 (litros)  \
# 0                                            4.256.500
# 1                                              512.000
# 2                                            3.496.000
# 3                                            1.406.000
# 4                                              993.000
# ..                                                 ...
# 492                                            264.000
# 493                                            409.000
# 494                                            271.000
# 495                                            864.000
# 496                                          6.304.569
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2014 (litros)  \
# 0                                            6.369.500
# 1                                              644.000
# 2                                            3.931.000
# 3                                            1.482.000
# 4                                            1.049.000
# ..                                                 ...
# 492                                            294.000
# 493                                            467.000
# 494                                            319.000
# 495                                            781.500
# 496                                          7.045.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2015 (litros)  \
# 0                                            6.891.000
# 1                                              708.000
# 2                                            3.987.000
# 3                                            1.448.000
# 4                                            1.028.000
# ..                                                 ...
# 492                                            350.000
# 493                                            446.000
# 494                                            276.000
# 495                                            836.880
# 496                                          6.189.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2016 (litros)  \
# 0                                            5.816.000
# 1                                              950.000
# 2                                            3.906.000
# 3                                            1.436.000
# 4                                            1.074.964
# ..                                                 ...
# 492                                            318.000
# 493                                            421.000
# 494                                            281.000
# 495                                            776.000
# 496                                          5.774.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2017 (litros)  \
# 0                                            6.492.766
# 1                                              939.000
# 2                                            3.890.842
# 3                                            1.406.000
# 4                                            1.015.000
# ..                                                 ...
# 492                                            327.000
# 493                                            424.975
# 494                                            220.000
# 495                                            740.000
# 496                                          6.614.200
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2018 (litros)  \
# 0                                            6.842.399
# 1                                              888.000
# 2                                            3.467.360
# 3                                            1.318.000
# 4                                              870.000
# ..                                                 ...
# 492                                            346.000
# 493                                            442.926
# 494                                            215.000
# 495                                            777.000
# 496                                          6.358.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2019 (litros)  \
# 0                                            7.047.000
# 1                                              788.000
# 2                                            3.265.000
# 3                                            1.361.000
# 4                                              855.000
# ..                                                 ...
# 492                                            376.000
# 493                                            430.000
# 494                                            230.000
# 495                                            842.000
# 496                                          6.397.000
#
#     /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2020 (litros)
# 0                                            7.232.000
# 1                                              716.000
# 2                                            3.006.000
# 3                                            1.170.000
# 4                                              840.000
# ..                                                 ...
# 492                                            425.000
# 493                                            458.000
# 494                                            235.000
# 495                                            819.000
# 496                                          7.171.000
#
# [497 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 33 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Município                                                           497 non-null    object
#  1   ibge                                                                497 non-null    int64
#  2   latitude                                                            497 non-null    float64
#  3   longitude                                                           497 non-null    float64
#  4   /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1992 (litros)  497 non-null    object
#  5   /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1993 (litros)  497 non-null    object
#  6   /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1994 (litros)  497 non-null    object
#  7   /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1995 (litros)  497 non-null    object
#  8   /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1996 (litros)  497 non-null    object
#  9   /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1997 (litros)  497 non-null    object
#  10  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1998 (litros)  497 non-null    object
#  11  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 1999 (litros)  497 non-null    object
#  12  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2000 (litros)  497 non-null    object
#  13  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2001 (litros)  497 non-null    object
#  14  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2002 (litros)  497 non-null    object
#  15  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2003 (litros)  497 non-null    object
#  16  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2004 (litros)  497 non-null    object
#  17  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2005 (litros)  497 non-null    object
#  18  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2006 (litros)  497 non-null    object
#  19  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2007 (litros)  497 non-null    object
#  20  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2008 (litros)  497 non-null    object
#  21  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2009 (litros)  497 non-null    object
#  22  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2010 (litros)  497 non-null    object
#  23  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2011 (litros)  497 non-null    object
#  24  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2012 (litros)  497 non-null    object
#  25  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2013 (litros)  497 non-null    object
#  26  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2014 (litros)  497 non-null    object
#  27  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2015 (litros)  497 non-null    object
#  28  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2016 (litros)  497 non-null    object
#  29  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2017 (litros)  497 non-null    object
#  30  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2018 (litros)  497 non-null    object
#  31  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2019 (litros)  497 non-null    object
#  32  /Comércio/Vendas de Combustíveis/Gasolina Automotiva 2020 (litros)  497 non-null    object
# dtypes: float64(2), int64(1), object(30)
# memory usage: 128.3+ KB

# %%
brasil = folium.Map(
    location=[-30.3852768,-52.315788], #coordenadas
    zoom_start=7
)
brasil
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ecadac8ae2d1711e74d271c92766813 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ecadac8ae2d1711e74d271c92766813&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ecadac8ae2d1711e74d271c92766813 = L.map(
#                 &quot;map_3ecadac8ae2d1711e74d271c92766813&quot;,
#                 {
#                     center: [-30.3852768, -52.315788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6950266589b0f867687099c7ec486aa9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for indice, municipio in df.iterrows():
  folium.Marker(
      location=[municipio["latitude"],municipio["longitude"]],
      icon=folium.map.Icon(color="green")
  ).add_to(brasil)

brasil
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ecadac8ae2d1711e74d271c92766813 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ecadac8ae2d1711e74d271c92766813&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ecadac8ae2d1711e74d271c92766813 = L.map(
#                 &quot;map_3ecadac8ae2d1711e74d271c92766813&quot;,
#                 {
#                     center: [-30.3852768, -52.315788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6950266589b0f867687099c7ec486aa9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var marker_bce99958521b2535d25ff36c2d50df5e = L.marker(
#                 [-31.86075999999, -54.16705999999],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var icon_92d01f81b296324ad92cceed74b0c91e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bce99958521b2535d25ff36c2d50df5e.setIcon(icon_92d01f81b296324ad92cceed74b0c91e);
#
#
#             var marker_69374b0a91add8e979a3db479db4d3fa = L.marker(
#                 [-28.1672, -52.03099999999],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var icon_37129679b3fda2e38ede497f9a87d28b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_69374b0a91add8e979a3db479db4d3fa.setIcon(icon_37129679b3fda2e38ede497f9a87d28b);
#
#
#             var marker_d1b7454e486ee6cd09ea0067789ac921 = L.marker(
#                 [-29.6447, -53.2515],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var icon_bca0fe9c5c4a49566cdc4c2790374993 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1b7454e486ee6cd09ea0067789ac921.setIcon(icon_bca0fe9c5c4a49566cdc4c2790374993);
#
#
#             var marker_d31dc53b3fdbe1c4db2bb1de6b0fca27 = L.marker(
#                 [-28.2342, -53.7757],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var icon_150823f71c2d53b57e55c4b32fdd4e0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d31dc53b3fdbe1c4db2bb1de6b0fca27.setIcon(icon_150823f71c2d53b57e55c4b32fdd4e0c);
#
#
#             var marker_a66d682909cd23c65c6910eecd962910 = L.marker(
#                 [-27.6579, -54.76489999999],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var icon_85aa7a23e6536d57a7bc3ff07738ca63 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a66d682909cd23c65c6910eecd962910.setIcon(icon_85aa7a23e6536d57a7bc3ff07738ca63);
#
#
#             var marker_68159ff204d2c8262ce4e5e761e00fec = L.marker(
#                 [-29.79019999999, -55.79489999999],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d271c92766813);
#
#
#             var icon_8035ee68b0f582545e3c879de12d1b9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68159ff204d2c8262ce4e5e761e00fec.setIcon(icon_8035ee68b0f582545e3c879de12d1b9a);
#
#
#             var marker_4609b4452168e4098cd6952a7f94c95b = L.marker(
#                 [-27.83449999999, -54.0557],
#                 {}
#             ).addTo(map_3ecadac8ae2d1711e74d
