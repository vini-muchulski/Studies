# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in c:\users\cliente\appdata\roaming\python\python311\site-packages (0.14.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\cliente\appdata\roaming\python\python311\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in d:\anaconda\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\cliente\appdata\roaming\python\python311\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\cliente\appdata\roaming\python\python311\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in d:\anaconda\lib\site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in d:\anaconda\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\cliente\appdata\roaming\python\python311\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\cliente\appdata\roaming\python\python311\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)

# %% [markdown]
# # eleicoes 2018

# %%
df_mapa = gpd.read_file("BR_Municipios_2022.shp",encoding="latin1")

# %%
df_mapa.head()
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
# 3  1100049                 Cacoal       RO  3793.000
# 4  1100056             Cerejeiras       RO  2783.300
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...

# %%
#verificando tamanho e colunas
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CD_MUN    5572 non-null   object
#  1   NM_MUN    5572 non-null   object
#  2   SIGLA_UF  5572 non-null   object
#  3   AREA_KM2  5572 non-null   float64
#  4   geometry  5572 non-null   geometry
# dtypes: float64(1), geometry(1), object(3)
# memory usage: 217.8+ KB

# %%
#exibir o mapa(plotar shapefile)
df_mapa.plot()
# Out:
# <Axes: >

# %%
fig,ax = plt.subplots(1,figsize=(12,12))

#DESENHAR MAPA
df_mapa.plot(ax=ax)

plt.show()

# %%
#carregar arquivo com o resultado da eleicao
df_votacao = pd.read_csv("votacao_candidato_munzona_2018_BR.csv",
                        sep=";",encoding="latin1")
df_votacao.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 1  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 2  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 3  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 4  09/04/2023   06:27:07         2018                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 0         1         295  Eleição Geral Federal 2018  07/10/2018
# 1         1         295  Eleição Geral Federal 2018  07/10/2018
# 2         1         295  Eleição Geral Federal 2018  07/10/2018
# 3         1         295  Eleição Geral Federal 2018  07/10/2018
# 4         1         295  Eleição Geral Federal 2018  07/10/2018
#
#   TP_ABRANGENCIA  ... DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO      NM_COLIGACAO  \
# 0              F  ...                  #NULO#  280000050592  ESSA É A SOLUÇÃO
# 1              F  ...                  #NULO#  280000050592  ESSA É A SOLUÇÃO
# 2              F  ...                  #NULO#  280000050592  ESSA É A SOLUÇÃO
# 3              F  ...                  #NULO#  280000050592  ESSA É A SOLUÇÃO
# 4              F  ...                  #NULO#  280000050592  ESSA É A SOLUÇÃO
#
#    DS_COMPOSICAO_COLIGACAO ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  \
# 0                MDB / PHS                   N                 49
# 1                MDB / PHS                   N               1015
# 2                MDB / PHS                   N                234
# 3                MDB / PHS                   N                 56
# 4                MDB / PHS                   N                 85
#
#    NM_TIPO_DESTINACAO_VOTOS QT_VOTOS_NOMINAIS_VALIDOS  CD_SIT_TOT_TURNO  \
# 0                    Válido                        49                 4
# 1                    Válido                      1015                 4
# 2                    Válido                       234                 4
# 3                    Válido                        56                 4
# 4                    Válido                        85                 4
#
#    DS_SIT_TOT_TURNO
# 0        NÃO ELEITO
# 1        NÃO ELEITO
# 2        NÃO ELEITO
# 3        NÃO ELEITO
# 4        NÃO ELEITO
#
# [5 rows x 44 columns]

# %%
df_votacao.head().T
# Out:
#                                                           0  \
# DT_GERACAO                                       09/04/2023
# HH_GERACAO                                         06:27:07
# ANO_ELEICAO                                            2018
# CD_TIPO_ELEICAO                                           2
# NM_TIPO_ELEICAO                           Eleição Ordinária
# NR_TURNO                                                  1
# CD_ELEICAO                                              295
# DS_ELEICAO                       Eleição Geral Federal 2018
# DT_ELEICAO                                       07/10/2018
# TP_ABRANGENCIA                                            F
# SG_UF                                                    SC
# SG_UE                                                    BR
# NM_UE                                                BRASIL
# CD_MUNICIPIO                                          81876
# NM_MUNICIPIO                                     LAURENTINO
# NR_ZONA                                                 102
# CD_CARGO                                                  1
# DS_CARGO                                         Presidente
# SQ_CANDIDATO                                   280000622281
# NR_CANDIDATO                                             15
# NM_CANDIDATO                   HENRIQUE DE CAMPOS MEIRELLES
# NM_URNA_CANDIDATO                        HENRIQUE MEIRELLES
# NM_SOCIAL_CANDIDATO                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                  12
# DS_SITUACAO_CANDIDATURA                                APTO
# CD_DETALHE_SITUACAO_CAND                                  2
# DS_DETALHE_SITUACAO_CAND                           DEFERIDO
# TP_AGREMIACAO                                     Coligação
# NR_PARTIDO                                               15
# SG_PARTIDO                                              MDB
# NM_PARTIDO                 Movimento Democrático Brasileiro
# NR_FEDERACAO                                             -1
# NM_FEDERACAO                                         #NULO#
# SG_FEDERACAO                                         #NULO#
# DS_COMPOSICAO_FEDERACAO                              #NULO#
# SQ_COLIGACAO                                   280000050592
# NM_COLIGACAO                               ESSA É A SOLUÇÃO
# DS_COMPOSICAO_COLIGACAO                           MDB / PHS
# ST_VOTO_EM_TRANSITO                                       N
# QT_VOTOS_NOMINAIS                                        49
# NM_TIPO_DESTINACAO_VOTOS                             Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                49
# CD_SIT_TOT_TURNO                                          4
# DS_SIT_TOT_TURNO                                 NÃO ELEITO
#
#                                                           1  \
# DT_GERACAO                                       09/04/2023
# HH_GERACAO                                         06:27:07
# ANO_ELEICAO                                            2018
# CD_TIPO_ELEICAO                                           2
# NM_TIPO_ELEICAO                           Eleição Ordinária
# NR_TURNO                                                  1
# CD_ELEICAO                                              295
# DS_ELEICAO                       Eleição Geral Federal 2018
# DT_ELEICAO                                       07/10/2018
# TP_ABRANGENCIA                                            F
# SG_UF                                                    MT
# SG_UE                                                    BR
# NM_UE                                                BRASIL
# CD_MUNICIPIO                                          90670
# NM_MUNICIPIO                                         CUIABÁ
# NR_ZONA                                                  39
# CD_CARGO                                                  1
# DS_CARGO                                         Presidente
# SQ_CANDIDATO                                   280000622281
# NR_CANDIDATO                                             15
# NM_CANDIDATO                   HENRIQUE DE CAMPOS MEIRELLES
# NM_URNA_CANDIDATO                        HENRIQUE MEIRELLES
# NM_SOCIAL_CANDIDATO                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                  12
# DS_SITUACAO_CANDIDATURA                                APTO
# CD_DETALHE_SITUACAO_CAND                                  2
# DS_DETALHE_SITUACAO_CAND                           DEFERIDO
# TP_AGREMIACAO                                     Coligação
# NR_PARTIDO                                               15
# SG_PARTIDO                                              MDB
# NM_PARTIDO                 Movimento Democrático Brasileiro
# NR_FEDERACAO                                             -1
# NM_FEDERACAO                                         #NULO#
# SG_FEDERACAO                                         #NULO#
# DS_COMPOSICAO_FEDERACAO                              #NULO#
# SQ_COLIGACAO                                   280000050592
# NM_COLIGACAO                               ESSA É A SOLUÇÃO
# DS_COMPOSICAO_COLIGACAO                           MDB / PHS
# ST_VOTO_EM_TRANSITO                                       N
# QT_VOTOS_NOMINAIS                                      1015
# NM_TIPO_DESTINACAO_VOTOS                             Válido
# QT_VOTOS_NOMINAIS_VALIDOS                              1015
# CD_SIT_TOT_TURNO                                          4
# DS_SIT_TOT_TURNO                                 NÃO ELEITO
#
#                                                           2  \
# DT_GERACAO                                       09/04/2023
# HH_GERACAO                                         06:27:07
# ANO_ELEICAO                                            2018
# CD_TIPO_ELEICAO                                           2
# NM_TIPO_ELEICAO                           Eleição Ordinária
# NR_TURNO                                                  1
# CD_ELEICAO                                              295
# DS_ELEICAO                       Eleição Geral Federal 2018
# DT_ELEICAO                                       07/10/2018
# TP_ABRANGENCIA                                            F
# SG_UF                                                    AM
# SG_UE                                                    BR
# NM_UE                                                BRASIL
# CD_MUNICIPIO                                           2810
# NM_MUNICIPIO                                           TEFÉ
# NR_ZONA                                                   9
# CD_CARGO                                                  1
# DS_CARGO                                         Presidente
# SQ_CANDIDATO                                   280000622281
# NR_CANDIDATO                                             15
# NM_CANDIDATO                   HENRIQUE DE CAMPOS MEIRELLES
# NM_URNA_CANDIDATO                        HENRIQUE MEIRELLES
# NM_SOCIAL_CANDIDATO                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                  12
# DS_SITUACAO_CANDIDATURA                                APTO
# CD_DETALHE_SITUACAO_CAND                                  2
# DS_DETALHE_SITUACAO_CAND                           DEFERIDO
# TP_AGREMIACAO                                     Coligação
# NR_PARTIDO                                               15
# SG_PARTIDO                                              MDB
# NM_PARTIDO                 Movimento Democrático Brasileiro
# NR_FEDERACAO                                             -1
# NM_FEDERACAO                                         #NULO#
# SG_FEDERACAO                                         #NULO#
# DS_COMPOSICAO_FEDERACAO                              #NULO#
# SQ_COLIGACAO                                   280000050592
# NM_COLIGACAO                               ESSA É A SOLUÇÃO
# DS_COMPOSICAO_COLIGACAO                           MDB / PHS
# ST_VOTO_EM_TRANSITO                                       N
# QT_VOTOS_NOMINAIS                                       234
# NM_TIPO_DESTINACAO_VOTOS                             Válido
# QT_VOTOS_NOMINAIS_VALIDOS                               234
# CD_SIT_TOT_TURNO                                          4
# DS_SIT_TOT_TURNO                                 NÃO ELEITO
#
#                                                           3  \
# DT_GERACAO                                       09/04/2023
# HH_GERACAO                                         06:27:07
# ANO_ELEICAO                                            2018
# CD_TIPO_ELEICAO                                           2
# NM_TIPO_ELEICAO                           Eleição Ordinária
# NR_TURNO                                                  1
# CD_ELEICAO                                              295
# DS_ELEICAO                       Eleição Geral Federal 2018
# DT_ELEICAO                                       07/10/2018
# TP_ABRANGENCIA                                            F
# SG_UF                                                    PR
# SG_UE                                                    BR
# NM_UE                                                BRASIL
# CD_MUNICIPIO                                          75000
# NM_MUNICIPIO                                   ITAIPULÂNDIA
# NR_ZONA                                                 122
# CD_CARGO                                                  1
# DS_CARGO                                         Presidente
# SQ_CANDIDATO                                   280000622281
# NR_CANDIDATO                                             15
# NM_CANDIDATO                   HENRIQUE DE CAMPOS MEIRELLES
# NM_URNA_CANDIDATO                        HENRIQUE MEIRELLES
# NM_SOCIAL_CANDIDATO                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                  12
# DS_SITUACAO_CANDIDATURA                                APTO
# CD_DETALHE_SITUACAO_CAND                                  2
# DS_DETALHE_SITUACAO_CAND                           DEFERIDO
# TP_AGREMIACAO                                     Coligação
# NR_PARTIDO                                               15
# SG_PARTIDO                                              MDB
# NM_PARTIDO                 Movimento Democrático Brasileiro
# NR_FEDERACAO                                             -1
# NM_FEDERACAO                                         #NULO#
# SG_FEDERACAO                                         #NULO#
# DS_COMPOSICAO_FEDERACAO                              #NULO#
# SQ_COLIGACAO                                   280000050592
# NM_COLIGACAO                               ESSA É A SOLUÇÃO
# DS_COMPOSICAO_COLIGACAO                           MDB / PHS
# ST_VOTO_EM_TRANSITO                                       N
# QT_VOTOS_NOMINAIS                                        56
# NM_TIPO_DESTINACAO_VOTOS                             Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                56
# CD_SIT_TOT_TURNO                                          4
# DS_SIT_TOT_TURNO                                 NÃO ELEITO
#
#                                                           4
# DT_GERACAO                                       09/04/2023
# HH_GERACAO                                         06:27:07
# ANO_ELEICAO                                            2018
# CD_TIPO_ELEICAO                                           2
# NM_TIPO_ELEICAO                           Eleição Ordinária
# NR_TURNO                                                  1
# CD_ELEICAO                                              295
# DS_ELEICAO                       Eleição Geral Federal 2018
# DT_ELEICAO                                       07/10/2018
# TP_ABRANGENCIA                                            F
# SG_UF                                                    MT
# SG_UE                                                    BR
# NM_UE                                                BRASIL
# CD_MUNICIPIO                                          91995
# NM_MUNICIPIO                          SÃO JOSÉ DO RIO CLARO
# NR_ZONA                                                  29
# CD_CARGO                                                  1
# DS_CARGO                                         Presidente
# SQ_CANDIDATO                                   280000622281
# NR_CANDIDATO                                             15
# NM_CANDIDATO                   HENRIQUE DE CAMPOS MEIRELLES
# NM_URNA_CANDIDATO                        HENRIQUE MEIRELLES
# NM_SOCIAL_CANDIDATO                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                  12
# DS_SITUACAO_CANDIDATURA                                APTO
# CD_DETALHE_SITUACAO_CAND                                  2
# DS_DETALHE_SITUACAO_CAND                           DEFERIDO
# TP_AGREMIACAO                                     Coligação
# NR_PARTIDO                                               15
# SG_PARTIDO                                              MDB
# NM_PARTIDO                 Movimento Democrático Brasileiro
# NR_FEDERACAO                                             -1
# NM_FEDERACAO                                         #NULO#
# SG_FEDERACAO                                         #NULO#
# DS_COMPOSICAO_FEDERACAO                              #NULO#
# SQ_COLIGACAO                                   280000050592
# NM_COLIGACAO                               ESSA É A SOLUÇÃO
# DS_COMPOSICAO_COLIGACAO                           MDB / PHS
# ST_VOTO_EM_TRANSITO                                       N
# QT_VOTOS_NOMINAIS                                        85
# NM_TIPO_DESTINACAO_VOTOS                             Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                85
# CD_SIT_TOT_TURNO                                          4
# DS_SIT_TOT_TURNO                                 NÃO ELEITO

# %%
#separar dados do 2 turno
df_votacao=df_votacao[df_votacao["NR_TURNO"]==2]
df_votacao.sample(3).T
# Out:
#                                                                58803  \
# DT_GERACAO                                                09/04/2023
# HH_GERACAO                                                  06:27:07
# ANO_ELEICAO                                                     2018
# CD_TIPO_ELEICAO                                                    2
# NM_TIPO_ELEICAO                                    Eleição Ordinária
# NR_TURNO                                                           2
# CD_ELEICAO                                                       296
# DS_ELEICAO                                Eleição Geral Federal 2018
# DT_ELEICAO                                                28/10/2018
# TP_ABRANGENCIA                                                     F
# SG_UF                                                             AP
# SG_UE                                                             BR
# NM_UE                                                         BRASIL
# CD_MUNICIPIO                                                    6114
# NM_MUNICIPIO                                          FERREIRA GOMES
# NR_ZONA                                                           12
# CD_CARGO                                                           1
# DS_CARGO                                                  Presidente
# SQ_CANDIDATO                                            280000614517
# NR_CANDIDATO                                                      17
# NM_CANDIDATO                                  JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                           #NULO#
# CD_SITUACAO_CANDIDATURA                                           12
# DS_SITUACAO_CANDIDATURA                                         APTO
# CD_DETALHE_SITUACAO_CAND                                           2
# DS_DETALHE_SITUACAO_CAND                                    DEFERIDO
# TP_AGREMIACAO                                              Coligação
# NR_PARTIDO                                                        17
# SG_PARTIDO                                                       PSL
# NM_PARTIDO                                    Partido Social Liberal
# NR_FEDERACAO                                                      -1
# NM_FEDERACAO                                                  #NULO#
# SG_FEDERACAO                                                  #NULO#
# DS_COMPOSICAO_FEDERACAO                                       #NULO#
# SQ_COLIGACAO                                            280000050386
# NM_COLIGACAO               BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                   PSL / PRTB
# ST_VOTO_EM_TRANSITO                                                N
# QT_VOTOS_NOMINAIS                                               1659
# NM_TIPO_DESTINACAO_VOTOS                                      Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                       1659
# CD_SIT_TOT_TURNO                                                   1
# DS_SIT_TOT_TURNO                                              ELEITO
#
#                                                 40970  \
# DT_GERACAO                                 09/04/2023
# HH_GERACAO                                   06:27:07
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 Eleição Geral Federal 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              BA
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    36331
# NM_MUNICIPIO                               ITAPITANGA
# NR_ZONA                                           135
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# TP_AGREMIACAO                               Coligação
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                2870
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                        2870
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO
#
#                                                                47578
# DT_GERACAO                                                09/04/2023
# HH_GERACAO                                                  06:27:07
# ANO_ELEICAO                                                     2018
# CD_TIPO_ELEICAO                                                    2
# NM_TIPO_ELEICAO                                    Eleição Ordinária
# NR_TURNO                                                           2
# CD_ELEICAO                                                       296
# DS_ELEICAO                                Eleição Geral Federal 2018
# DT_ELEICAO                                                28/10/2018
# TP_ABRANGENCIA                                                     F
# SG_UF                                                             PI
# SG_UE                                                             BR
# NM_UE                                                         BRASIL
# CD_MUNICIPIO                                                   11738
# NM_MUNICIPIO                                    REDENÇÃO DO GURGUÉIA
# NR_ZONA                                                           15
# CD_CARGO                                                           1
# DS_CARGO                                                  Presidente
# SQ_CANDIDATO                                            280000614517
# NR_CANDIDATO                                                      17
# NM_CANDIDATO                                  JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                           #NULO#
# CD_SITUACAO_CANDIDATURA                                           12
# DS_SITUACAO_CANDIDATURA                                         APTO
# CD_DETALHE_SITUACAO_CAND                                           2
# DS_DETALHE_SITUACAO_CAND                                    DEFERIDO
# TP_AGREMIACAO                                              Coligação
# NR_PARTIDO                                                        17
# SG_PARTIDO                                                       PSL
# NM_PARTIDO                                    Partido Social Liberal
# NR_FEDERACAO                                                      -1
# NM_FEDERACAO                                                  #NULO#
# SG_FEDERACAO                                                  #NULO#
# DS_COMPOSICAO_FEDERACAO                                       #NULO#
# SQ_COLIGACAO                                            280000050386
# NM_COLIGACAO               BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                   PSL / PRTB
# ST_VOTO_EM_TRANSITO                                                N
# QT_VOTOS_NOMINAIS                                                945
# NM_TIPO_DESTINACAO_VOTOS                                      Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                        945
# CD_SIT_TOT_TURNO                                                   1
# DS_SIT_TOT_TURNO                                              ELEITO

# %%
df_votacao["CD_MUNICIPIO"].nunique()
# Out:
# 5708

# %%
#mas o brasil tem 5570 municipios
df_votacao[df_votacao["SG_UF"]=="ZZ"].sample(4).T
# Out:
#                                                 26401  \
# DT_GERACAO                                 09/04/2023
# HH_GERACAO                                   06:27:07
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 Eleição Geral Federal 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    29858
# NM_MUNICIPIO                                     KIEV
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# TP_AGREMIACAO                               Coligação
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                   7
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                           7
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO
#
#                                                 61503  \
# DT_GERACAO                                 09/04/2023
# HH_GERACAO                                   06:27:07
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 Eleição Geral Federal 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    30457
# NM_MUNICIPIO                                 ROTTERDÃ
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# TP_AGREMIACAO                               Coligação
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                1047
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                        1047
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO
#
#                                                                32676  \
# DT_GERACAO                                                09/04/2023
# HH_GERACAO                                                  06:27:07
# ANO_ELEICAO                                                     2018
# CD_TIPO_ELEICAO                                                    2
# NM_TIPO_ELEICAO                                    Eleição Ordinária
# NR_TURNO                                                           2
# CD_ELEICAO                                                       296
# DS_ELEICAO                                Eleição Geral Federal 2018
# DT_ELEICAO                                                28/10/2018
# TP_ABRANGENCIA                                                     F
# SG_UF                                                             ZZ
# SG_UE                                                             BR
# NM_UE                                                         BRASIL
# CD_MUNICIPIO                                                   29599
# NM_MUNICIPIO                                         COPENHAGUE-DINA
# NR_ZONA                                                            1
# CD_CARGO                                                           1
# DS_CARGO                                                  Presidente
# SQ_CANDIDATO                                            280000614517
# NR_CANDIDATO                                                      17
# NM_CANDIDATO                                  JAIR MESSIAS BOLSONARO
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NM_SOCIAL_CANDIDATO                                           #NULO#
# CD_SITUACAO_CANDIDATURA                                           12
# DS_SITUACAO_CANDIDATURA                                         APTO
# CD_DETALHE_SITUACAO_CAND                                           2
# DS_DETALHE_SITUACAO_CAND                                    DEFERIDO
# TP_AGREMIACAO                                              Coligação
# NR_PARTIDO                                                        17
# SG_PARTIDO                                                       PSL
# NM_PARTIDO                                    Partido Social Liberal
# NR_FEDERACAO                                                      -1
# NM_FEDERACAO                                                  #NULO#
# SG_FEDERACAO                                                  #NULO#
# DS_COMPOSICAO_FEDERACAO                                       #NULO#
# SQ_COLIGACAO                                            280000050386
# NM_COLIGACAO               BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS
# DS_COMPOSICAO_COLIGACAO                                   PSL / PRTB
# ST_VOTO_EM_TRANSITO                                                N
# QT_VOTOS_NOMINAIS                                                190
# NM_TIPO_DESTINACAO_VOTOS                                      Válido
# QT_VOTOS_NOMINAIS_VALIDOS                                        190
# CD_SIT_TOT_TURNO                                                   1
# DS_SIT_TOT_TURNO                                              ELEITO
#
#                                                 45685
# DT_GERACAO                                 09/04/2023
# HH_GERACAO                                   06:27:07
# ANO_ELEICAO                                      2018
# CD_TIPO_ELEICAO                                     2
# NM_TIPO_ELEICAO                     Eleição Ordinária
# NR_TURNO                                            2
# CD_ELEICAO                                        296
# DS_ELEICAO                 Eleição Geral Federal 2018
# DT_ELEICAO                                 28/10/2018
# TP_ABRANGENCIA                                      F
# SG_UF                                              ZZ
# SG_UE                                              BR
# NM_UE                                          BRASIL
# CD_MUNICIPIO                                    29742
# NM_MUNICIPIO                                HAMAMATSU
# NR_ZONA                                             1
# CD_CARGO                                            1
# DS_CARGO                                   Presidente
# SQ_CANDIDATO                             280000629808
# NR_CANDIDATO                                       13
# NM_CANDIDATO                          FERNANDO HADDAD
# NM_URNA_CANDIDATO                     FERNANDO HADDAD
# NM_SOCIAL_CANDIDATO                            #NULO#
# CD_SITUACAO_CANDIDATURA                            12
# DS_SITUACAO_CANDIDATURA                          APTO
# CD_DETALHE_SITUACAO_CAND                            2
# DS_DETALHE_SITUACAO_CAND                     DEFERIDO
# TP_AGREMIACAO                               Coligação
# NR_PARTIDO                                         13
# SG_PARTIDO                                         PT
# NM_PARTIDO                  Partido dos Trabalhadores
# NR_FEDERACAO                                       -1
# NM_FEDERACAO                                   #NULO#
# SG_FEDERACAO                                   #NULO#
# DS_COMPOSICAO_FEDERACAO                        #NULO#
# SQ_COLIGACAO                             280000050703
# NM_COLIGACAO                     O POVO FELIZ DE NOVO
# DS_COMPOSICAO_COLIGACAO           PT / PC do B / PROS
# ST_VOTO_EM_TRANSITO                                 N
# QT_VOTOS_NOMINAIS                                 399
# NM_TIPO_DESTINACAO_VOTOS                       Válido
# QT_VOTOS_NOMINAIS_VALIDOS                         399
# CD_SIT_TOT_TURNO                                    4
# DS_SIT_TOT_TURNO                           NÃO ELEITO

# %%
#Qnts cidades de fora do brasil estao no dataset
df_votacao[df_votacao["SG_UF"]=="ZZ"]["CD_MUNICIPIO"].nunique()
# Out:
# 138

# %%
#eliminar cidades do exterior
df_votacao = df_votacao[df_votacao["SG_UF"] != "ZZ"]

# %%
df_votacao["CD_MUNICIPIO"].nunique()
# Out:
# 5570

# %%
df_votacao.head()
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 10998  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 10999  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 11000  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 11001  09/04/2023   06:27:07         2018                2  Eleição Ordinária
# 11002  09/04/2023   06:27:07         2018                2  Eleição Ordinária
#
#        NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 10998         2         296  Eleição Geral Federal 2018  28/10/2018
# 10999         2         296  Eleição Geral Federal 2018  28/10/2018
# 11000         2         296  Eleição Geral Federal 2018  28/10/2018
# 11001         2         296  Eleição Geral Federal 2018  28/10/2018
# 11002         2         296  Eleição Geral Federal 2018  28/10/2018
#
#       TP_ABRANGENCIA  ... DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO  \
# 10998              F  ...                  #NULO#  280000050386
# 10999              F  ...                  #NULO#  280000050386
# 11000              F  ...                  #NULO#  280000050386
# 11001              F  ...                  #NULO#  280000050386
# 11002              F  ...                  #NULO#  280000050386
#
#                                     NM_COLIGACAO  DS_COMPOSICAO_COLIGACAO  \
# 10998  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS               PSL / PRTB
# 10999  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS               PSL / PRTB
# 11000  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS               PSL / PRTB
# 11001  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS               PSL / PRTB
# 11002  BRASIL ACIMA DE TUDO, DEUS ACIMA DE TODOS               PSL / PRTB
#
#       ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  NM_TIPO_DESTINACAO_VOTOS  \
# 10998                   N               8161                    Válido
# 10999                   N               2862                    Válido
# 11000                   N               2064                    Válido
# 11001                   N               1475                    Válido
# 11002                   N               4663                    Válido
#
#       QT_VOTOS_NOMINAIS_VALIDOS  CD_SIT_TOT_TURNO  DS_SIT_TOT_TURNO
# 10998                      8161                 1            ELEITO
# 10999                      2862                 1            ELEITO
# 11000                      2064                 1            ELEITO
# 11001                      1475                 1            ELEITO
# 11002                      4663                 1            ELEITO
#
# [5 rows x 44 columns]

# %%
#eliminar algumas colunas 
df_votacao = df_votacao[["SG_UF","CD_MUNICIPIO","NM_MUNICIPIO",
"NR_CANDIDATO","NM_URNA_CANDIDATO","QT_VOTOS_NOMINAIS"]]

# %%
df_votacao.head()
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10998    PR         78115         RESERVA            17    JAIR BOLSONARO
# 10999    PR         75507         PEROBAL            17    JAIR BOLSONARO
# 11000    PA          4995  NOVA TIMBOTEUA            17    JAIR BOLSONARO
# 11001    GO         94110           ITAJÁ            17    JAIR BOLSONARO
# 11002    PA          4804        BELTERRA            17    JAIR BOLSONARO
#
#        QT_VOTOS_NOMINAIS
# 10998               8161
# 10999               2862
# 11000               2064
# 11001               1475
# 11002               4663

# %%
#agregar os dados por municipio
df_votacao.groupby(["SG_UF","CD_MUNICIPIO","NM_MUNICIPIO","NM_URNA_CANDIDATO"]).sum()
# Out:
#                                                              NR_CANDIDATO  \
# SG_UF CD_MUNICIPIO NM_MUNICIPIO           NM_URNA_CANDIDATO
# AC    1007         BUJARI                 FERNANDO HADDAD              13
#                                           JAIR BOLSONARO               17
#       1015         CAPIXABA               FERNANDO HADDAD              13
#                                           JAIR BOLSONARO               17
#       1023         PORTO ACRE             FERNANDO HADDAD              13
# ...                                                                   ...
# TO    96954        ALIANÇA DO TOCANTINS   JAIR BOLSONARO               17
#       96970        APARECIDA DO RIO NEGRO FERNANDO HADDAD              13
#                                           JAIR BOLSONARO               17
#       96997        BARROLÂNDIA            FERNANDO HADDAD              13
#                                           JAIR BOLSONARO               17
#
#                                                              QT_VOTOS_NOMINAIS
# SG_UF CD_MUNICIPIO NM_MUNICIPIO           NM_URNA_CANDIDATO
# AC    1007         BUJARI                 FERNANDO HADDAD                 1274
#                                           JAIR BOLSONARO                  4676
#       1015         CAPIXABA               FERNANDO HADDAD                 1086
#                                           JAIR BOLSONARO                  3895
#       1023         PORTO ACRE             FERNANDO HADDAD                 2059
# ...                                                                        ...
# TO    96954        ALIANÇA DO TOCANTINS   JAIR BOLSONARO                  1215
#       96970        APARECIDA DO RIO NEGRO FERNANDO HADDAD                 1291
#                                           JAIR BOLSONARO                  1171
#       96997        BARROLÂNDIA            FERNANDO HADDAD                 1545
#                                           JAIR BOLSONARO                  1501
#
# [11140 rows x 2 columns]

# %%
#agregar os dados por municipio
df_votacao = df_votacao.groupby(["SG_UF","CD_MUNICIPIO","NM_MUNICIPIO","NM_URNA_CANDIDATO"]).sum().reset_index()

# %%
df_votacao.sample(4)
# Out:
#      SG_UF  CD_MUNICIPIO     NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# 8870    SC         80195  ANITA GARIBALDI   FERNANDO HADDAD            13
# 2298    MA          7218            AXIXÁ   FERNANDO HADDAD            13
# 7538    RN         17370         LUCRÉCIA   FERNANDO HADDAD            13
# 3397    MG         44474      DIVISA NOVA    JAIR BOLSONARO            17
#
#       QT_VOTOS_NOMINAIS
# 8870               2473
# 2298               5448
# 7538               2135
# 3397               1760

# %%
#ordenar o df pela qntd de votos e dps deixar apenas o primeiro, o maior candidato de cada cidade
df_votacao.sort_values(by="QT_VOTOS_NOMINAIS",ascending=False).head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO    JAIR BOLSONARO           986
# 10722    SP         71072       SÃO PAULO   FERNANDO HADDAD           754
# 7369     RJ         60011  RIO DE JANEIRO    JAIR BOLSONARO           833
# 7368     RJ         60011  RIO DE JANEIRO   FERNANDO HADDAD           637
# 1607     DF         97012        BRASÍLIA    JAIR BOLSONARO           323
# 1054     BA         38490        SALVADOR   FERNANDO HADDAD           247
# 2937     MG         41238  BELO HORIZONTE    JAIR BOLSONARO           306
# 6659     PR         75353        CURITIBA    JAIR BOLSONARO           170
# 1376     CE         13897       FORTALEZA   FERNANDO HADDAD           221
# 309      AM          2550          MANAUS    JAIR BOLSONARO           221
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 10722            2424125
# 7369             2179896
# 7368             1105393
# 1607             1080411
# 1054              985532
# 2937              901513
# 6659              786377
# 1376              739265
# 309               686999

# %%
df_votacao.sort_values(by="QT_VOTOS_NOMINAIS",ascending=False,inplace=True)
#dropar linhas duplicadas
df_votacao.drop_duplicates(subset="CD_MUNICIPIO",keep="first",inplace=True)

df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO    JAIR BOLSONARO           986
# 7369     RJ         60011  RIO DE JANEIRO    JAIR BOLSONARO           833
# 1607     DF         97012        BRASÍLIA    JAIR BOLSONARO           323
# 1054     BA         38490        SALVADOR   FERNANDO HADDAD           247
# 2937     MG         41238  BELO HORIZONTE    JAIR BOLSONARO           306
# 6659     PR         75353        CURITIBA    JAIR BOLSONARO           170
# 1376     CE         13897       FORTALEZA   FERNANDO HADDAD           221
# 309      AM          2550          MANAUS    JAIR BOLSONARO           221
# 2013     GO         93734         GOIÂNIA    JAIR BOLSONARO           153
# 5834     PE         25313          RECIFE   FERNANDO HADDAD           143
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 7369             2179896
# 1607             1080411
# 1054              985532
# 2937              901513
# 6659              786377
# 1376              739265
# 309               686999
# 2013              528525
# 5834              482673

# %%
df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO    JAIR BOLSONARO           986
# 7369     RJ         60011  RIO DE JANEIRO    JAIR BOLSONARO           833
# 1607     DF         97012        BRASÍLIA    JAIR BOLSONARO           323
# 1054     BA         38490        SALVADOR   FERNANDO HADDAD           247
# 2937     MG         41238  BELO HORIZONTE    JAIR BOLSONARO           306
# 6659     PR         75353        CURITIBA    JAIR BOLSONARO           170
# 1376     CE         13897       FORTALEZA   FERNANDO HADDAD           221
# 309      AM          2550          MANAUS    JAIR BOLSONARO           221
# 2013     GO         93734         GOIÂNIA    JAIR BOLSONARO           153
# 5834     PE         25313          RECIFE   FERNANDO HADDAD           143
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 7369             2179896
# 1607             1080411
# 1054              985532
# 2937              901513
# 6659              786377
# 1376              739265
# 309               686999
# 2013              528525
# 5834              482673

# %%
#Agora vamos criar uma coluna q representa o resultado da eleicao
#Bolsonaro seria o true e Haddad o false
df_votacao["RESULTADO"] = df_votacao["NM_URNA_CANDIDATO"].apply(lambda x: x =="JAIR BOLSONARO")

# %%
df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO    JAIR BOLSONARO           986
# 7369     RJ         60011  RIO DE JANEIRO    JAIR BOLSONARO           833
# 1607     DF         97012        BRASÍLIA    JAIR BOLSONARO           323
# 1054     BA         38490        SALVADOR   FERNANDO HADDAD           247
# 2937     MG         41238  BELO HORIZONTE    JAIR BOLSONARO           306
# 6659     PR         75353        CURITIBA    JAIR BOLSONARO           170
# 1376     CE         13897       FORTALEZA   FERNANDO HADDAD           221
# 309      AM          2550          MANAUS    JAIR BOLSONARO           221
# 2013     GO         93734         GOIÂNIA    JAIR BOLSONARO           153
# 5834     PE         25313          RECIFE   FERNANDO HADDAD           143
#
#        QT_VOTOS_NOMINAIS  RESULTADO
# 10723            3694834       True
# 7369             2179896       True
# 1607             1080411       True
# 1054              985532      False
# 2937              901513       True
# 6659              786377       True
# 1376              739265      False
# 309               686999       True
# 2013              528525       True
# 5834              482673      False

# %%
df_votacao[df_votacao["NM_MUNICIPIO"] == "BELO HORIZONTE"]
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# 2937    MG         41238  BELO HORIZONTE    JAIR BOLSONARO           306
#
#       QT_VOTOS_NOMINAIS  RESULTADO
# 2937             901513       True

# %%
df_votacao.dtypes
# Out:
# SG_UF                object
# CD_MUNICIPIO          int64
# NM_MUNICIPIO         object
# NM_URNA_CANDIDATO    object
# NR_CANDIDATO          int64
# QT_VOTOS_NOMINAIS     int64
# RESULTADO              bool
# dtype: object

# %%
df_mapa.head(3)
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...

# %%
#linkar cod tse e cod ibge via github do estadao
link = "https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv"
df_equivalencia = pd.read_csv(link)

df_equivalencia.head(10)
# Out:
#                 chave             NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0       ac acrelandia       ACRELÂNDIA  AC      1200013     1120    NaN
# 1     ac assis brasil     ASSIS BRASIL  AC      1200054     1570    NaN
# 2        ac brasileia        BRASILÉIA  AC      1200104     1058    NaN
# 3           ac bujari           BUJARI  AC      1200138     1007    NaN
# 4         ac capixaba         CAPIXABA  AC      1200179     1015    NaN
# 5  ac cruzeiro do sul  CRUZEIRO DO SUL  AC      1200203     1074    NaN
# 6   ac epitaciolandia   EPITACIOLÂNDIA  AC      1200252     1112    NaN
# 7            ac feijo            FEIJÓ  AC      1200302     1139    NaN
# 8           ac jordao           JORDÃO  AC      1200328     1104    NaN
# 9      ac mancio lima      MÂNCIO LIMA  AC      1200336     1090    NaN

# %%
#reindexacao df_votacao pelo cod do tse
df_vot_novo = df_votacao.copy()

# %%
df_vot_novo.set_index("CD_MUNICIPIO",drop=False,inplace=True)
df_vot_novo.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO    JAIR BOLSONARO
# 60011           RJ         60011  RIO DE JANEIRO    JAIR BOLSONARO
# 97012           DF         97012        BRASÍLIA    JAIR BOLSONARO
# 38490           BA         38490        SALVADOR   FERNANDO HADDAD
# 41238           MG         41238  BELO HORIZONTE    JAIR BOLSONARO
#
#               NR_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO
# 71072                  986            3694834       True
# 60011                  833            2179896       True
# 97012                  323            1080411       True
# 38490                  247             985532      False
# 41238                  306             901513       True

# %%
df_equi_novo = df_equivalencia.copy()

df_equi_novo.set_index("COD_TSE",drop=False,inplace=True)
df_equi_novo.head()
# Out:
#                    chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# COD_TSE
# 1120       ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1570     ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 1058        ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 1007           ac bujari        BUJARI  AC      1200138     1007    NaN
# 1015         ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
#verificando tamanho
df_vot_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   int64
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NM_URNA_CANDIDATO  5570 non-null   object
#  4   NR_CANDIDATO       5570 non-null   int64
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 310.0+ KB

# %%
df_equi_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 1120 to 96431
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chave        5570 non-null   object
#  1   NOME         5570 non-null   object
#  2   UF           5570 non-null   object
#  3   GEOCOD_IBGE  5570 non-null   int64
#  4   COD_TSE      5570 non-null   int64
#  5   AJUSTE       29 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 304.6+ KB

# %%
df_voto_equi = df_vot_novo.join(df_equi_novo)
df_voto_equi.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO NM_URNA_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO    JAIR BOLSONARO
# 60011           RJ         60011  RIO DE JANEIRO    JAIR BOLSONARO
# 97012           DF         97012        BRASÍLIA    JAIR BOLSONARO
# 38490           BA         38490        SALVADOR   FERNANDO HADDAD
# 41238           MG         41238  BELO HORIZONTE    JAIR BOLSONARO
#
#               NR_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO              chave  \
# CD_MUNICIPIO
# 71072                  986            3694834       True       sp sao paulo
# 60011                  833            2179896       True  rj rio de janeiro
# 97012                  323            1080411       True        df brasilia
# 38490                  247             985532      False        ba salvador
# 41238                  306             901513       True  mg belo horizonte
#
#                         NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# CD_MUNICIPIO
# 71072              SÃO PAULO  SP      3550308    71072    NaN
# 60011         RIO DE JANEIRO  RJ      3304557    60011    NaN
# 97012               BRASÍLIA  DF      5300108    97012    NaN
# 38490               SALVADOR  BA      2927408    38490    NaN
# 41238         BELO HORIZONTE  MG      3106200    41238    NaN

# %%
df_voto_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   int64
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NM_URNA_CANDIDATO  5570 non-null   object
#  4   NR_CANDIDATO       5570 non-null   int64
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
#  7   chave              5570 non-null   object
#  8   NOME               5570 non-null   object
#  9   UF                 5570 non-null   object
#  10  GEOCOD_IBGE        5570 non-null   int64
#  11  COD_TSE            5570 non-null   int64
#  12  AJUSTE             29 non-null     object
# dtypes: bool(1), int64(5), object(7)
# memory usage: 700.2+ KB

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CD_MUN    5572 non-null   object
#  1   NM_MUN    5572 non-null   object
#  2   SIGLA_UF  5572 non-null   object
#  3   AREA_KM2  5572 non-null   float64
#  4   geometry  5572 non-null   geometry
# dtypes: float64(1), geometry(1), object(3)
# memory usage: 217.8+ KB

# %%
df_mapa.head()
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
# 3  1100049                 Cacoal       RO  3793.000
# 4  1100056             Cerejeiras       RO  2783.300
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...

# %%
df_voto_equi["GEOCOD_IBGE"] = df_voto_equi["GEOCOD_IBGE"].astype(str)
df_voto_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              5570 non-null   object
#  1   CD_MUNICIPIO       5570 non-null   int64
#  2   NM_MUNICIPIO       5570 non-null   object
#  3   NM_URNA_CANDIDATO  5570 non-null   object
#  4   NR_CANDIDATO       5570 non-null   int64
#  5   QT_VOTOS_NOMINAIS  5570 non-null   int64
#  6   RESULTADO          5570 non-null   bool
#  7   chave              5570 non-null   object
#  8   NOME               5570 non-null   object
#  9   UF                 5570 non-null   object
#  10  GEOCOD_IBGE        5570 non-null   object
#  11  COD_TSE            5570 non-null   int64
#  12  AJUSTE             29 non-null     object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 700.2+ KB

# %%
#unificar df mapa com df votacao/equivalencia
#unificar os indices
df_mapa.set_index("CD_MUN",drop=False,inplace=True)

# %%
df_mapa.head()
# Out:
#           CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# CD_MUN
# 1100015  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1100023  1100023              Ariquemes       RO  4426.571
# 1100031  1100031                 Cabixi       RO  1314.352
# 1100049  1100049                 Cacoal       RO  3793.000
# 1100056  1100056             Cerejeiras       RO  2783.300
#
#                                                   geometry
# CD_MUN
# 1100015  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1100023  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 1100031  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 1100049  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 1100056  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...

# %%
df_voto_equi.set_index("GEOCOD_IBGE",drop=False,inplace=True)

# %%
#juntando os data frames
df_mapa_novo = df_mapa.join(df_voto_equi)
df_mapa_novo.head().T
# Out:
# CD_MUN                                                       1100015  \
# CD_MUN                                                       1100015
# NM_MUN                                         Alta Floresta D'Oeste
# SIGLA_UF                                                          RO
# AREA_KM2                                                    7067.127
# geometry           POLYGON ((-62.0080637729999 -12.1337851349999,...
# SG_UF                                                             RO
# CD_MUNICIPIO                                                   310.0
# NM_MUNICIPIO                                   ALTA FLORESTA D OESTE
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NR_CANDIDATO                                                    17.0
# QT_VOTOS_NOMINAIS                                             8524.0
# RESULTADO                                                       True
# chave                                      ro alta floresta do oeste
# NOME                                          ALTA FLORESTA DO OESTE
# UF                                                                RO
# GEOCOD_IBGE                                                  1100015
# COD_TSE                                                        310.0
# AJUSTE                                                             S
#
# CD_MUN                                                       1100023  \
# CD_MUN                                                       1100023
# NM_MUN                                                     Ariquemes
# SIGLA_UF                                                          RO
# AREA_KM2                                                    4426.571
# geometry           POLYGON ((-63.179325881 -10.139244048, -63.177...
# SG_UF                                                             RO
# CD_MUNICIPIO                                                    78.0
# NM_MUNICIPIO                                               ARIQUEMES
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NR_CANDIDATO                                                    17.0
# QT_VOTOS_NOMINAIS                                            37325.0
# RESULTADO                                                       True
# chave                                                   ro ariquemes
# NOME                                                       ARIQUEMES
# UF                                                                RO
# GEOCOD_IBGE                                                  1100023
# COD_TSE                                                         78.0
# AJUSTE                                                           NaN
#
# CD_MUN                                                       1100031  \
# CD_MUN                                                       1100031
# NM_MUN                                                        Cabixi
# SIGLA_UF                                                          RO
# AREA_KM2                                                    1314.352
# geometry           POLYGON ((-60.524079765 -13.32137253, -60.3716...
# SG_UF                                                             RO
# CD_MUNICIPIO                                                   450.0
# NM_MUNICIPIO                                                  CABIXI
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NR_CANDIDATO                                                    17.0
# QT_VOTOS_NOMINAIS                                             2142.0
# RESULTADO                                                       True
# chave                                                      ro cabixi
# NOME                                                          CABIXI
# UF                                                                RO
# GEOCOD_IBGE                                                  1100031
# COD_TSE                                                        450.0
# AJUSTE                                                           NaN
#
# CD_MUN                                                       1100049  \
# CD_MUN                                                       1100049
# NM_MUN                                                        Cacoal
# SIGLA_UF                                                          RO
# AREA_KM2                                                      3793.0
# geometry           POLYGON ((-61.3550247649999 -11.5045183089999,...
# SG_UF                                                             RO
# CD_MUNICIPIO                                                    94.0
# NM_MUNICIPIO                                                  CACOAL
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NR_CANDIDATO                                                    17.0
# QT_VOTOS_NOMINAIS                                            35962.0
# RESULTADO                                                       True
# chave                                                      ro cacoal
# NOME                                                          CACOAL
# UF                                                                RO
# GEOCOD_IBGE                                                  1100049
# COD_TSE                                                         94.0
# AJUSTE                                                           NaN
#
# CD_MUN                                                       1100056
# CD_MUN                                                       1100056
# NM_MUN                                                    Cerejeiras
# SIGLA_UF                                                          RO
# AREA_KM2                                                      2783.3
# geometry           POLYGON ((-60.8213452849999 -13.1191007429999,...
# SG_UF                                                             RO
# CD_MUNICIPIO                                                   272.0
# NM_MUNICIPIO                                              CEREJEIRAS
# NM_URNA_CANDIDATO                                     JAIR BOLSONARO
# NR_CANDIDATO                                                    17.0
# QT_VOTOS_NOMINAIS                                             7656.0
# RESULTADO                                                       True
# chave                                                  ro cerejeiras
# NOME                                                      CEREJEIRAS
# UF                                                                RO
# GEOCOD_IBGE                                                  1100056
# COD_TSE                                                        272.0
# AJUSTE                                                           NaN

# %%
df_mapa_novo["QT_VOTOS_NOMINAIS"].nlargest(5)
# Out:
# CD_MUN
# 3550308    3694834.0
# 3304557    2179896.0
# 5300108    1080411.0
# 2927408     985532.0
# 3106200     901513.0
# Name: QT_VOTOS_NOMINAIS, dtype: float64

# %%
df_mapa_novo.loc["2927408"]
# Out:
# CD_MUN                                                         2927408
# NM_MUN                                                        Salvador
# SIGLA_UF                                                            BA
# AREA_KM2                                                       693.442
# geometry             POLYGON ((-38.377100615 -12.953674443, -38.377...
# SG_UF                                                               BA
# CD_MUNICIPIO                                                   38490.0
# NM_MUNICIPIO                                                  SALVADOR
# NM_URNA_CANDIDATO                                      FERNANDO HADDAD
# NR_CANDIDATO                                                     247.0
# QT_VOTOS_NOMINAIS                                             985532.0
# RESULTADO                                                        False
# chave                                                      ba salvador
# NOME                                                          SALVADOR
# UF                                                                  BA
# GEOCOD_IBGE                                                    2927408
# COD_TSE                                                        38490.0
# AJUSTE                                                             NaN
# Name: 2927408, dtype: object

# %%
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 1100015 to 5300108
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CD_MUN             5572 non-null   object
#  1   NM_MUN             5572 non-null   object
#  2   SIGLA_UF           5572 non-null   object
#  3   AREA_KM2           5572 non-null   float64
#  4   geometry           5572 non-null   geometry
#  5   SG_UF              5570 non-null   object
#  6   CD_MUNICIPIO       5570 non-null   float64
#  7   NM_MUNICIPIO       5570 non-null   object
#  8   NM_URNA_CANDIDATO  5570 non-null   object
#  9   NR_CANDIDATO       5570 non-null   float64
#  10  QT_VOTOS_NOMINAIS  5570 non-null   float64
#  11  RESULTADO          5570 non-null   object
#  12  chave              5570 non-null   object
#  13  NOME               5570 non-null   object
#  14  UF                 5570 non-null   object
#  15  GEOCOD_IBGE        5570 non-null   object
#  16  COD_TSE            5570 non-null   float64
#  17  AJUSTE             29 non-null     object
# dtypes: float64(5), geometry(1), object(12)
# memory usage: 956.1+ KB

# %%
#descobrir 2 municipios a mais no mapa
df_mapa_novo[df_mapa_novo["NR_CANDIDATO"].isnull()]
# Out:
#           CD_MUN           NM_MUN SIGLA_UF   AREA_KM2  \
# CD_MUN
# 4300001  4300001      Lagoa Mirim       RS   2884.340
# 4300002  4300002  Lagoa dos Patos       RS  10201.524
#
#                                                   geometry SG_UF  \
# CD_MUN
# 4300001  POLYGON ((-52.62752 -32.15022, -52.62816 -32.1...   NaN
# 4300002  POLYGON ((-52.09720 -32.16167, -52.09926 -32.1...   NaN
#
#          CD_MUNICIPIO NM_MUNICIPIO NM_URNA_CANDIDATO  NR_CANDIDATO  \
# CD_MUN
# 4300001           NaN          NaN               NaN           NaN
# 4300002           NaN          NaN               NaN           NaN
#
#          QT_VOTOS_NOMINAIS RESULTADO chave NOME   UF GEOCOD_IBGE  COD_TSE  \
# CD_MUN
# 4300001                NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300002                NaN       NaN   NaN  NaN  NaN         NaN      NaN
#
#         AJUSTE
# CD_MUN
# 4300001    NaN
# 4300002    NaN

# %%
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 1100015 to 5300108
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CD_MUN             5572 non-null   object
#  1   NM_MUN             5572 non-null   object
#  2   SIGLA_UF           5572 non-null   object
#  3   AREA_KM2           5572 non-null   float64
#  4   geometry           5572 non-null   geometry
#  5   SG_UF              5570 non-null   object
#  6   CD_MUNICIPIO       5570 non-null   float64
#  7   NM_MUNICIPIO       5570 non-null   object
#  8   NM_URNA_CANDIDATO  5570 non-null   object
#  9   NR_CANDIDATO       5570 non-null   float64
#  10  QT_VOTOS_NOMINAIS  5570 non-null   float64
#  11  RESULTADO          5570 non-null   object
#  12  chave              5570 non-null   object
#  13  NOME               5570 non-null   object
#  14  UF                 5570 non-null   object
#  15  GEOCOD_IBGE        5570 non-null   object
#  16  COD_TSE            5570 non-null   float64
#  17  AJUSTE             29 non-null     object
# dtypes: float64(5), geometry(1), object(12)
# memory usage: 956.1+ KB

# %%
#vamos desenhar o mapa (false = 0 ; true = 1 green
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap
#cmap = ListedColormap=(['red',"green", "blue", "k"])

fig,ax = plt.subplots(1,figsize=(12,12))

cmap = LinearSegmentedColormap.from_list('custom_colormap', ['red', 'green', 'green', 'green'])
ax = df_mapa_novo.plot(column="RESULTADO",cmap=cmap,legend=True,linewidth=1,ax=ax,edgecolor="grey")

ax.set_axis_off()

ax.set_title("resultado eleicao 2018 segundo turno",fontdict={"fontsize" :"25", "fontweight" : "3"})

plt.show()
